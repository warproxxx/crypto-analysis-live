# %%
import pandas as pd
import numpy as np
from glob import glob

# %%
def get_stats(symbol):
    stats = {}

    curr_folder = "algorithm/data/backtest/{}".format(symbol)
    portfolio = pd.read_csv(curr_folder + "/portfolio.csv")
    stats['return'] = round(((portfolio.iloc[-1]['Value'] / portfolio.iloc[0]['Value']) - 1) * 100, 2)
    stats['vs_hodl'] = round(((portfolio.iloc[-1]['Value'] / portfolio.iloc[-1]['hodl']) - 1) * 100, 2)
    stats['start_cash'] = round(portfolio.iloc[0]['Value'], 2)
    stats['end_cash'] = round(portfolio.iloc[-1]['Value'], 2)
    stats['end_hodl'] = round(portfolio.iloc[-1]['hodl'], 2)

    portfolio = portfolio.rename(columns={'Value': symbol})
    return portfolio[['Date', symbol]], stats

def get_symbols():
    files = glob('algorithm/data/backtest/*')
    symbols = [file.split('/')[-1].replace('.csv', '') for file in files]
    symbols.sort()

    return symbols

# %%
files = glob('algorithm/data/backtest/*')

# %%
coinwise_stats = {}
combined_portfolio = pd.DataFrame()
btc = pd.read_csv('algorithm/data/backtest/BTC/portfolio.csv')
combined_portfolio['Date'] = btc['Date']
combined_portfolio['btc_portfolio'] = btc['hodl']
dates = []

# %%
for file in files:
    symbol = file.split('/')[-1].replace('.csv', '')
    curr_df, coinwise_stats[symbol] = get_stats(symbol)
    combined_portfolio = curr_df.merge(combined_portfolio, on='Date', how='right')

# %%
combined_portfolio.columns
# Out:
# Index(['Date', 'EOS', 'XTZ', 'ETH', 'ZEC', 'LTC', 'XRP', 'ZRX', 'MIOTA', 'SAN',
#        'LINK', 'XMR', 'ETC', 'NEO', 'ETP', 'TRX', 'BTC', 'BCHABC', 'OMG',
#        'BNB', 'BTG', 'DASH', 'ADA', 'BSV', 'XLM', 'btc_portfolio'],
#       dtype='object')

# %%
combined_portfolio['btc_portfolio'] = combined_portfolio['btc_portfolio'] * (len(combined_portfolio.columns) - 2)

# %%
combined_portfolio
# Out:
#           Date           EOS           XTZ           ETH           ZEC  \
# 0   2019-08-09  10000.000000  10000.000000  10000.000000  10000.000000
# 1   2019-08-10  10000.000000  10000.000000  10000.000000  10000.000000
# 2   2019-08-11  10000.000000   9799.320735  10064.148561  10000.000000
# 3   2019-08-12   9875.187292   9804.635952  10087.191353  10000.000000
# 4   2019-08-13   9987.388192   9900.379317  10213.423383   9988.295391
# 5   2019-08-14   9987.388192  10460.824822  10201.742603  10180.483246
# 6   2019-08-15   9987.388192  10460.824822  10201.742603  11002.707097
# 7   2019-08-16   9987.388192  10526.688738  10662.389405  10980.335931
# 8   2019-08-17   9987.388192  10526.688738  10684.844208  11004.529355
# 9   2019-08-18   9987.388192  10526.688738  10466.050461  11130.291228
# 10  2019-08-19   9987.388192  10526.688738   9982.976129  11130.291228
# 11  2019-08-20   9987.388192  10526.688738   9597.590393  11130.291228
# 12  2019-08-21   9924.287685  10526.688738   9531.546599  10981.229436
# 15   9183.058968  10002.449669  11465.140364  10102.056459   9180.727044
# 16   9523.086432  10037.199001  11465.140364  10102.056459   9249.279696
# 17   9523.086432   9977.891071  11465.140364  10102.056459   9249.279696
# 18   9523.086432   9805.659988  11465.140364   9948.169473   9249.279696
#
#             DASH           ADA           BSV           XLM  btc_portfolio
# 0   10000.000000  10000.000000  10000.000000  10000.000000  240000.000000
# 1   10000.000000  10000.000000  10000.000000  10000.000000  239888.715592
# 2   10412.144205   9543.049618  10279.641295  10000.000000  229335.311723
# 3   10693.889205   9013.359601   9954.253806   9747.416362  233373.519369
# 4   10693.889205   9276.619364  10115.707134   9965.673664  230398.178982
# 5   10693.889205   9400.196306  10072.983741  10062.963371  220822.054546
# 6   10714.780599   9324.053055  10072.983741  10117.727055  203872.427602
# 7   10490.239087   9293.793538  10072.983741  10162.143564  209073.860810
# 8   10650.845230   9586.484953  10072.983741  10270.721388  209697.458163
# 9   10749.969411   9586.484953  10072.983741  10491.791818  206387.050542
# 10  10325.969402   9586.484953  10015.037143  10066.203776  209116.351220
# 11  10239.800534   9586.484953  10049.420914   9989.265645  219811.592126
# 12  10239.800534   9586.484953  10245.275829   9921.004703  218210.513004
# 13  10239.800534   9493.754848  10676.578005   9662.106350  203705.096320
# 14  10239.800534   9443.675185  10851.389879   9511.246730  204469.316697
# 15  10239.800534   9443.675185  10851.389879   9511.246730  210040.214138
# 16  10144.040879   9443.675185  10851.389879   9670.778512  205232.930068
# 17  10267.356539   9443.675185  10851.389879   9867.487927  204412.055811
# 18  10156.131549   9443.675185  10867.613609   9773.446182  209844.960587
#
# [19 rows x 26 columns]

# %%
df = pd.DataFrame.from_dict(coinwise_stats)
df = df.T

# %%
combined_portfolio = combined_portfolio.set_index('Date')

# %%
div = pd.DataFrame(((combined_portfolio.iloc[-1] / combined_portfolio.iloc[0]) - 1) * 100).reset_index()
div.columns = ['Symbol', 'Change']

div['Change'] = div['Change'].round(2)

dictionary = dict(zip(div.Symbol,div.Change))
print(dictionary)
# Out:
# {'EOS': 5.0, 'XTZ': 9.48, 'ETH': -0.14, 'ZEC': 13.43, 'LTC': 12.42, 'XRP': -2.88, 'ZRX': 2.37, 'MIOTA': 14.46, 'SAN': 4.63, 'LINK': -4.49, 'XMR': -5.55, 'ETC': 10.73, 'NEO': -0.82, 'ETP': -6.1, 'TRX': 18.53, 'BTC': -4.77, 'BCHABC': -1.94, 'OMG': 14.65, 'BNB': -0.52, 'BTG': -7.51, 'DASH': 1.56, 'ADA': -5.56, 'BSV': 8.68, 'XLM': -2.27, 'btc_portfolio': -12.56}

# %%
combined_portfolio.drop('btc_portfolio', axis=1).sum(axis=1)
# Out:
# Date
# 2019-08-09    240000.000000
# 2019-08-10    239736.717104
# 2019-08-11    240309.652376
# 2019-08-12    237471.165064
# 2019-08-13    238839.288148
# 2019-08-14    240595.323090
# 2019-08-15    245980.453174
# 2019-08-16    244633.809435
# 2019-08-17    246435.531222
# 2019-08-18    246860.782824
# 2019-08-19    243659.252675
# 2019-08-20    242024.335819
# 2019-08-21    242772.649995
# 2019-08-22    246732.925635
# 2019-08-23    246885.198529
# 2019-08-24    246233.261238
# 2019-08-25    248209.864378
# 2019-08-26    248340.117769
# 2019-08-27    247338.529836
# dtype: float64

# %%
combined_portfolio['portfolio'] = combined_portfolio.drop('btc_portfolio', axis=1).sum(axis=1)

# %%
combined_portfolio = combined_portfolio[['portfolio', 'btc_portfolio']]

# %%
combined_portfolio = combined_portfolio.reset_index()
combined_portfolio = combined_portfolio.rename(columns={'Date': 'Time'})

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

def create_plot(df, col1, col1_display, col2, col2_display):
    hovertext = []

    for i in range(len(df['Time'])):
        hovertext.append('{}: '.format(col1_display)+str(round(df[col1][i], 2))
                         +'<br>{}: '.format(col2_display)+str(round(df[col2][i], 2))
                        )
    
    fig = go.Figure(layout=go.Layout(xaxis={'spikemode': 'across'}))
    
    

    fig.add_trace(go.Scatter(x=df['Time'], y=df[col1], name=col1_display, text=hovertext,
                            marker={'color': '#1f77b4'}
                            ))
    
    fig.add_trace(go.Scatter(x=df['Time'], y=df[col2], name=col2_display, text=hovertext, 
                             marker={'color': '#d62728'}))

    return fig

# %%
col1 = "portfolio"
col1_display = "Portfolio Movement"

col2 = "btc_portfolio"
col2_display = "Bitcoin Movement"
df = combined_portfolio

# %%
create_plot(combined_portfolio, 'portfolio', 'Portfolio Movement', 'btc_portfolio', 'Bitcoin HODL Portfolio')
# Out:
# <div>
#
#
#             <div id="cbfe4238-eae5-455f-b74a-05834ab147e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cbfe4238-eae5-455f-b74a-05834ab147e6")) {
#                     Plotly.newPlot(
#                         'cbfe4238-eae5-455f-b74a-05834ab147e6',
#                         [{"marker": {"color": "#1f77b4"}, "name": "Portfolio Movement", "text": ["Portfolio Movement: 240000.0<br>Bitcoin HODL Portfolio: 240000.0", "Portfolio Movement: 239736.72<br>Bitcoin HODL Portfolio: 239888.72", "Portfolio Movement: 240309.65<br>Bitcoin HODL Portfolio: 229335.31", "Portfolio Movement: 237471.17<br>Bitcoin HODL Portfolio: 233373.52", "Portfolio Movement: 238839.29<br>Bitcoin HODL Portfolio: 230398.18", "Portfolio Movement: 240595.32<br>Bitcoin HODL Portfolio: 220822.05", "Portfolio Movement: 245980.45<br>Bitcoin HODL Portfolio: 203872.43", "Portfolio Movement: 244633.81<br>Bitcoin HODL Portfolio: 209073.86", "Portfolio Movement: 246435.53<br>Bitcoin HODL Portfolio: 209697.46", "Portfolio Movement: 246860.78<br>Bitcoin HODL Portfolio: 206387.05", "Portfolio Movement: 243659.25<br>Bitcoin HODL Portfolio: 209116.35", "Portfolio Movement: 242024.34<br>Bitcoin HODL Portfolio: 219811.59", "Portfolio Movement: 242772.65<br>Bitcoin HODL Portfolio: 218210.